# %% [markdown]
# # Capstone Project - Food Access in Los Angeles
# ### Riley Franks, May 2019
# ### [Applied Data Science Capstone Course by IBM/Coursera](https://www.coursera.org/learn/applied-data-science-capstone/home/info)
# -----------------------------------------

# %% [markdown]
# ## Table of Contents
# * [Introduction: Business Problem](#introduction)
# * [Data](#data)
# * [Methodology](#methodology)
# * [Analysis](#analysis)
# * [Results and Discussion](#results)
# * [Conclusion](#conclusion)
# * [References](#references)

# %% [markdown]
# ## Introduction: Business Problem <a name="introduction"></a>

# %% [markdown]
# In the last decade, nutrition in the United States has come into focus as a national crisis.  Millions of Americans lack access to an adequate supply of fresh, healthy food.  And, according to the CDC, there appears to be a link between access to affordable nutritious foods and the incorporation of healthy foods into the populations’ diets. There is growing interest in the idea of "food desert" communities.  There's no standard definition, but generally these are neighborhoods that lack grocery stores and farmers' markets. The U.S. Department of Agriculture summarizes the problem well: "Some people and places, especially those with low income, may face greater barriers in accessing healthy and affordable food retailers, which may negatively affect diet and food security."
#
#
# This project will focus on Los Angeles County in California. We will analyze geographic variation in food access and population demographics, and overlay that onto a map of grocery stores, convenience stores, and restaurants in the area. Community planners and local governments may find this more useful than data reports and tables in getting an intuitive understanding of the food landscape in their cities.
#
# References:
# - "Officials seek to attract grocery stores to ‘food deserts’" (https://www.apnews.com/a2b0356365db4e5dbdb9c4a077be315e, Caitlin Morris, April 2019)
# - https://www.cdc.gov/healthcommunication/toolstemplates/entertainmented/tips/FoodDesert.html
# - http://americannutritionassociation.org/newsletter/usda-defines-food-deserts
# - https://www.ers.usda.gov/topics/food-choices-health/food-access/

# %% [markdown]
# ## Data <a name="data"></a>

# %% [markdown]
# The U.S. Department of Agriculture's Economic Research Service publishes a Food Access Research Atlas [1] with census-tract level data on food access in the United States. There are tons of indicators, but we will be exploring a few specific variables. We get counts of the total population in each census tract, the population living more than a 1/2 mile from a supermarket, and the low-income population living more than a 1/2 mile from a supermarket.
#
# The University of Southern California provides a crosswalk [2] to get latitude and longitude coordinates for a census tract. We will use this to connect the food access data to geospatial coordinates.
#
# Finally, we will access the Foursquare API [3] to look up the venues in each neighborhood. We will request information for each census tract using their latitude/longitude coordinates. The Foursquare data gives us the name, location, and category for each venue.  We'll use the category variable to subset our results to food-related venues.
#
#
# 1. https://www.ers.usda.gov/data-products/food-access-research-atlas/
# 2. https://usc.data.socrata.com/widgets/atat-mmad
# 3. https://developer.foursquare.com/

# %% [markdown]
# ## References <a name="references"></a>

# %% [markdown]
# - Course example of outstanding submission: https://cocl.us/coursera_capstone_notebook
# - https://www.governing.com/gov-data/census/2018-county-migration-census-data.html
# - https://www.census.gov/data/tables/2016/demo/geographic-mobility/county-to-county-migration-2012-2016.html
# - https://www.ers.usda.gov/topics/food-choices-health/food-access/
# - https://www.ers.usda.gov/data-products/food-access-research-atlas/
# - Infographic: https://socialwork.tulane.edu/blog/food-deserts-in-america

# %% [markdown]
# ----------------------------------------------------------------------------

# %% [markdown]
# # Work in Progress...

# %%
import numpy as np # library to handle data in a vectorized manner

import pandas as pd # library for data analysis
pd.set_option('display.max_columns', None)
pd.set_option('display.max_rows', None)

import json # library to handle JSON files

#!conda install -c conda-forge geopy --yes 
from geopy.geocoders import Nominatim # convert an address into latitude and longitude values

import requests # library to handle requests
from pandas.io.json import json_normalize # tranform JSON file into a pandas dataframe

# Matplotlib and associated plotting modules
import matplotlib.cm as cm
import matplotlib.colors as colors

# import k-means from clustering stage
from sklearn.cluster import KMeans

#!conda install -c conda-forge folium=0.5.0 --yes
import folium # map rendering library

import requests # library to fetch URLs

from bs4 import BeautifulSoup # library to scrape data from a webpage

print('Libraries imported.')
# Out:
# Libraries imported.

# %%
# @hidden_cell
CLIENT_ID = 'CN5NRP3FQ3PUY403DEAMPRRA25IZ5SF5YGWGIBK3FJUB5FLG' # your Foursquare ID
CLIENT_SECRET = 'AQ3N5JOFGUCUEY1RXYUSIM2ZFBURQRNOSTH43RDPQPE03GYE' # your Foursquare Secret
VERSION = '20180604' # Foursquare API version
LIMIT = 100

# %% [markdown]
# Use function set up in Week 3 assignment (based on the getNearbyVenues function from the Exploring NY lab)

# %%
# json downloaded from https://usc.data.socrata.com/resource/atat-mmad.json
# has latitude and longitude for all census tracts in Los Angeles
# Out:
# Data downloaded from: https://usc.data.socrata.com/widgets/atat-mmad

# %%
lat_lng_coords = pd.read_json('atat-mmad.json')
lat_lng_coords = lat_lng_coords[['geoid','latitude','longitude','neighborhood','tract_number']]
lat_lng_coords.head()
# Out:
#                   geoid   latitude   longitude neighborhood  tract_number
# 0  1400000US06037101110  34.259555 -118.293602      Tujunga        101110
# 1  1400000US06037101122  34.267357 -118.290240      Tujunga        101122
# 2  1400000US06037101210  34.251998 -118.292687      Tujunga        101210
# 3  1400000US06037101220  34.251190 -118.281014      Tujunga        101220
# 4  1400000US06037101300  34.245595 -118.271731      Tujunga        101300

# %%
food_atlas = pd.read_excel(
    'Food_Access_Research_Atlas_2015_LOS_ANGELES.xlsx',
    sheet_name='Food Access Research Atlas')

food_atlas = food_atlas[['CensusTract','State','County','Urban','POP2010',
                         'lapophalf','lapophalfshare','lalowihalf','lalowihalfshare']]
food_atlas.head()
# Out:
#    CensusTract       State       County  Urban  POP2010    lapophalf  \
# 0   6037101110  California  Los Angeles      1     4731  3461.636143
# 1   6037101122  California  Los Angeles      1     3664  3660.694039
# 2   6037101210  California  Los Angeles      1     5990  5329.504750
# 3   6037101220  California  Los Angeles      1     3363  1874.230204
# 4   6037101300  California  Los Angeles      1     4199   739.348889
#
#    lapophalfshare   lalowihalf  lalowihalfshare
# 0        0.731692  1443.337800         0.305081
# 1        0.999098   317.312226         0.086603
# 2        0.889734  3035.663558         0.506789
# 3        0.557309   681.286018         0.202583
# 4        0.176077    76.682345         0.018262

# %% [markdown]
# Combine food_atlas with lat_lng_coords

# %%
# Get last 6 digits of CensusTract to match tract_number in lat-long data
food_atlas['atlas_tract']=food_atlas['CensusTract'].astype(str).str[4:11]
# Put tract number in lat_lng_coords in string format
lat_lng_coords['tract_number']=lat_lng_coords['tract_number'].astype(str)

# Merge on tract number
food_and_coords = pd.merge(left=food_atlas,right=lat_lng_coords,how='inner',
              left_on='atlas_tract',right_on='tract_number',validate='1:1')
food_and_coords.drop(['atlas_tract','State','County','CensusTract','Urban','geoid'],axis=1,inplace=True)

food_and_coords.head()
# Out:
#    POP2010    lapophalf  lapophalfshare   lalowihalf  lalowihalfshare  \
# 0     4731  3461.636143        0.731692  1443.337800         0.305081
# 1     3664  3660.694039        0.999098   317.312226         0.086603
# 2     5990  5329.504750        0.889734  3035.663558         0.506789
# 3     3363  1874.230204        0.557309   681.286018         0.202583
# 4     4199   739.348889        0.176077    76.682345         0.018262
#
#     latitude   longitude neighborhood tract_number
# 0  34.259555 -118.293602      Tujunga       101110
# 1  34.267357 -118.290240      Tujunga       101122
# 2  34.251998 -118.292687      Tujunga       101210
# 3  34.251190 -118.281014      Tujunga       101220
# 4  34.245595 -118.271731      Tujunga       101300

# %% [markdown]
# ## Connect to FourSquare Data

# %% [markdown]
# Define a function to get information for all of the food-related venues in a census tract. (Heavily based on the Week 2 Lab Notebook)

# %%
def getNearbyFoodVenues(df, radius=500):
    """Loop through the input locations and request venue information from FourSquare.
    Output a single dataframe with all of the results."""
    names = df['neighborhood']+' - Census Tract ' + df['tract_number']
    latitudes = df['latitude']
    longitudes = df['longitude']
               
    venues_dict={}
    idx = 0
    for name, lat, lng in zip(names, latitudes, longitudes):
        print(f'Getting venues near {name}...')
            
        # create the API request URL
        url = 'https://api.foursquare.com/v2/venues/explore?&client_id={}&client_secret={}&v={}&ll={},{}&radius={}&limit={}'.format(
            CLIENT_ID, 
            CLIENT_SECRET, 
            VERSION, 
            lat, 
            lng, 
            radius, 
            LIMIT)
            
        # make the GET request
        results = requests.get(url).json()["response"]['groups'][0]['items']
        
        # return only relevant information for each nearby venue
        for venue in results:            
            venues_dict.update({idx :
                {'Neighborhood':name, 
                 'Neighborhood Latitude':lat, 
                 'Neighborhood Longitude':lng, 
                 'Venue':venue['venue']['name'], 
                 'Venue ID':venue['venue']['id'],
                 'Distance from Neighborhood':venue['venue']['location']['distance'],
                 'Venue Latitude':venue['venue']['location']['lat'], 
                 'Venue Longitude':venue['venue']['location']['lng'],  
                 'Venue Category':venue['venue']['categories'][0]['name'],
                 'Venue Type':venue['venue']['categories'][0]['icon']['prefix'].split('/')[-2] # get broader category bin from icon prefix
                }})
            idx = idx + 1

        print(f'    found {len(results):,} results')
    # Use helper method for creating a dataframe by rows
    nearby_venues = pd.DataFrame.from_dict(venues_dict, orient='index')
    
    print('---------------------------------------------------------')
    #De-duplicate, make sure each venue is only assigned to the closest neighborhood
    print(f'{nearby_venues.shape[0]:,} total venues collected.')
    nearby_venues = nearby_venues.loc[nearby_venues.groupby('Venue ID')['Distance from Neighborhood'].idxmin()]
    print(f'   ... {nearby_venues.shape[0]:,} remaining after de-duplication.')
    #Subset to food venues
    nearby_food_venues = nearby_venues.loc[nearby_venues['Venue Type']=='food',
                        ['Neighborhood','Venue','Venue Latitude','Venue Longitude','Venue Category']]
    print(f'   ... {nearby_venues.shape[0]:,} after subset to food venues.')
    
    # Add numeric code for venue category
    category_labels = nearby_food_venues['Venue Category'].value_counts().reset_index()
    category_labels.set_index('index',inplace=True)
    category_labels['Category Number']= range(1, 1 + category_labels.shape[0])
    category_labels = category_labels.to_dict()['Category Number']
    nearby_food_venues['Category Number']=nearby_food_venues['Venue Category'].map(category_labels)
    print(category_labels)
    
    
    return(nearby_food_venues)

# %% [markdown]
# Try it out...

# %%
venues = getNearbyFoodVenues(food_and_coords)
# Out:
# Getting venues near Tujunga - Census Tract 101110...
#     found 3 results
# Getting venues near Tujunga - Census Tract 101122...
#     found 0 results
# Getting venues near Tujunga - Census Tract 101210...
#     found 11 results
# Getting venues near Tujunga - Census Tract 101220...
#     found 4 results
# Getting venues near Tujunga - Census Tract 101300...
#     found 18 results
# Getting venues near Tujunga - Census Tract 101400...
#     found 0 results
# Getting venues near Shadow Hills - Census Tract 102103...
#     found 2 results
# Getting venues near Shadow Hills - Census Tract 102104...
#     found 2 results
# Getting venues near Sun Valley - Census Tract 102105...
#     found 3 results
# Getting venues near Shadow Hills - Census Tract 102107...
#     found 0 results
# Getting venues near Sunland - Census Tract 103101...
#     found 2 results
# Getting venues near Sunland - Census Tract 103102...
#     found 8 results
# Getting venues near Lake View Terrace - Census Tract 103200...
#     found 3 results
# Getting venues near Shadow Hills - Census Tract 103300...
#     found 1 results
# Getting venues near Sunland - Census Tract 103400...
#     found 2 results
# Getting venues near Lake View Terrace - Census Tract 104103...
#     found 0 results
# Getting venues near Pacoima - Census Tract 104105...
#     found 2 results
# Getting venues near Pacoima - Census Tract 104108...
#     found 10 results
# Getting venues near Lopez/Kagel Canyons - Census Tract 104124...
#     found 2 results
# Getting venues near Pacoima - Census Tract 104201...
#     found 1 results
# Getting venues near Pacoima - Census Tract 104203...
#     found 9 results
# Getting venues near Lake View Terrace - Census Tract 104204...
#     found 1 results
# Getting venues near Pacoima - Census Tract 104310...
#     found 8 results
# Getting venues near Pacoima - Census Tract 104320...
#     found 5 results
# Getting venues near Pacoima - Census Tract 104401...
#     found 1 results
# Getting venues near Pacoima - Census Tract 104403...
#     found 9 results
# Getting venues near Pacoima - Census Tract 104404...
#     found 6 results
# Getting venues near Pacoima - Census Tract 104500...
#     found 5 results
# Getting venues near Pacoima - Census Tract 104610...
#     found 2 results
# Getting venues near Pacoima - Census Tract 104620...
#     found 3 results
# Getting venues near Pacoima - Census Tract 104701...
#     found 6 results
# Getting venues near Pacoima - Census Tract 104703...
#     found 1 results
# Getting venues near Pacoima - Census Tract 104704...
#     found 0 results
# Getting venues near Pacoima - Census Tract 104810...
#     found 4 results
# Getting venues near Pacoima - Census Tract 104821...
#     found 15 results
# Getting venues near Pacoima - Census Tract 104822...
#     found 16 results
# Getting venues near Sylmar - Census Tract 106010...
#     found 4 results
# Getting venues near Sylmar - Census Tract 106020...
#     found 3 results
# Getting venues near Sylmar - Census Tract 106111...
#     found 3 results
# Getting venues near Sylmar - Census Tract 106112...
#     found 3 results
# Getting venues near Sylmar - Census Tract 106113...
#     found 2 results
# Getting venues near Sylmar - Census Tract 106114...
#     found 1 results
# Getting venues near Sylmar - Census Tract 106403...
#     found 4 results
# Getting venues near Sylmar - Census Tract 106405...
#     found 1 results
# Getting venues near Sylmar - Census Tract 106406...
#     found 5 results
# Getting venues near Sylmar - Census Tract 106407...
#     found 15 results
# Getting venues near Sylmar - Census Tract 106408...
#     found 9 results
# Getting venues near Sylmar - Census Tract 106510...
#     found 4 results
# Getting venues near Sylmar - Census Tract 106520...
#     found 5 results
# Getting venues near Granada Hills - Census Tract 106603...
#     found 0 results
# Getting venues near Sylmar - Census Tract 106604...
#     found 6 results
# Getting venues near Granada Hills - Census Tract 106641...
#     found 2 results
# Getting venues near Granada Hills - Census Tract 106642...
#     found 5 results
# Getting venues near Granada Hills - Census Tract 106643...
#     found 0 results
# Getting venues near Granada Hills - Census Tract 106645...
#     found 1 results
# Getting venues near Granada Hills - Census Tract 106646...
#     found 2 results
# Getting venues near Sylmar - Census Tract 106648...
#     found 1 results
# Getting venues near Sylmar - Census Tract 106649...
#     found 3 results
# Getting venues near Sylmar - Census Tract 107010...
#     found 6 results
# Getting venues near Sylmar - Census Tract 107020...
#     found 1 results
# Getting venues near Porter Ranch - Census Tract 108101...
#     found 6 results
# Getting venues near Porter Ranch - Census Tract 108102...
# Getting venues near Sun Valley - Census Tract 121802...
#     found 7 results
# Getting venues near Sun Valley - Census Tract 121900...
#     found 4 results
# Getting venues near Sun Valley - Census Tract 122000...
#     found 6 results
# Getting venues near Sun Valley - Census Tract 122120...
#     found 7 results
# Getting venues near Sun Valley - Census Tract 122121...
#     found 9 results
# Getting venues near Sun Valley - Census Tract 122122...
#     found 13 results
# Getting venues near Sun Valley - Census Tract 122200...
#     found 5 results
# Getting venues near Sun Valley - Census Tract 122410...
#     found 8 results
# Getting venues near Sun Valley - Census Tract 122420...
#     found 10 results
# Getting venues near Sun Valley - Census Tract 123010...
#     found 8 results
# Getting venues near Sun Valley - Census Tract 123020...
#     found 5 results
# Getting venues near North Hollywood - Census Tract 123103...
#     found 6 results
# Getting venues near North Hollywood - Census Tract 123104...
#     found 11 results
# Getting venues near North Hollywood - Census Tract 123203...
#     found 12 results
# Getting venues near North Hollywood - Census Tract 123204...
#     found 15 results
# Getting venues near North Hollywood - Census Tract 123205...
#     found 16 results
# Getting venues near North Hollywood - Census Tract 123206...
#     found 10 results
# Getting venues near North Hollywood - Census Tract 123301...
#     found 5 results
# Getting venues near Valley Glen - Census Tract 123303...
#     found 15 results
# Getting venues near Valley Glen - Census Tract 123304...
#     found 8 results
# Getting venues near Valley Glen - Census Tract 123410...
#     found 16 results
# Getting venues near Valley Glen - Census Tract 123420...
#     found 9 results
# Getting venues near Valley Glen - Census Tract 123510...
#     found 11 results
# Getting venues near Valley Glen - Census Tract 123520...
#     found 11 results
# Getting venues near Valley Glen - Census Tract 123601...
#     found 4 results
# Getting venues near Valley Glen - Census Tract 123602...
#     found 6 results
# Getting venues near Valley Glen - Census Tract 123700...
#     found 18 results
# Getting venues near Valley Glen - Census Tract 123800...
#     found 16 results
# Getting venues near North Hollywood - Census Tract 123901...
#     found 16 results
# Getting venues near North Hollywood - Census Tract 123902...
#     found 6 results
# Getting venues near Valley Village - Census Tract 124000...
#     found 16 results
# Getting venues near North Hollywood - Census Tract 124102...
#     found 23 results
# Getting venues near North Hollywood - Census Tract 124103...
#     found 13 results
# Getting venues near North Hollywood - Census Tract 124104...
#     found 21 results
# Getting venues near North Hollywood - Census Tract 124105...
#     found 19 results
# Getting venues near North Hollywood - Census Tract 124201...
#     found 12 results
# Getting venues near North Hollywood - Census Tract 124203...
#     found 7 results
# Getting venues near North Hollywood - Census Tract 124204...
#     found 16 results
# Getting venues near North Hollywood - Census Tract 124300...
#     found 8 results
# Getting venues near Valley Glen - Census Tract 124400...
#     found 9 results
# Getting venues near Valley Glen - Census Tract 124500...
#     found 8 results
# Getting venues near Sherman Oaks - Census Tract 124600...
#     found 5 results
# Getting venues near Valley Village - Census Tract 124902...
#     found 26 results
# Getting venues near Valley Village - Census Tract 124903...
#     found 28 results
# Getting venues near Valley Village - Census Tract 125100...
#     found 21 results
# Getting venues near Valley Village - Census Tract 125200...
#     found 20 results
# Getting venues near North Hollywood - Census Tract 125310...
#     found 26 results
# Getting venues near North Hollywood - Census Tract 125320...
#     found 69 results
# Getting venues near North Hollywood - Census Tract 125401...
#     found 34 results
# Getting venues near North Hollywood - Census Tract 125402...
#     found 33 results
# Getting venues near North Hollywood - Census Tract 125501...
#     found 26 results
# Getting venues near Toluca Lake - Census Tract 125502...
#     found 21 results
# Getting venues near Toluca Lake - Census Tract 125600...
#     found 2 results
# Getting venues near Van Nuys - Census Tract 127102...
#     found 4 results
# Getting venues near Van Nuys - Census Tract 127103...
#     found 23 results
# Getting venues near Van Nuys - Census Tract 127104...
#     found 4 results
# Getting venues near Van Nuys - Census Tract 127210...
#     found 2 results
# Getting venues near Van Nuys - Census Tract 127220...
#     found 13 results
# Getting venues near Van Nuys - Census Tract 127300...
#     found 9 results
# Getting venues near Van Nuys - Census Tract 127400...
#     found 7 results
# Getting venues near Van Nuys - Census Tract 127520...
#     found 19 results
# Getting venues near Van Nuys - Census Tract 127603...
#     found 3 results
# Getting venues near Van Nuys - Census Tract 127604...
#     found 4 results
# Getting venues near Van Nuys - Census Tract 127605...
#     found 8 results
# Getting venues near Van Nuys - Census Tract 127606...
#     found 5 results
# Getting venues near Van Nuys - Census Tract 127711...
#     found 17 results
# Getting venues near Van Nuys - Census Tract 127712...
#     found 9 results
# Getting venues near Van Nuys - Census Tract 127803...
#     found 12 results
# Getting venues near Van Nuys - Census Tract 127804...
# ---------------------------------------------------------------------------
# JSONDecodeError                           Traceback (most recent call last)
# <ipython-input-8-fd33210408fe> in <module>
# ----> 1 venues = getNearbyFoodVenues(food_and_coords)
#
# <ipython-input-7-4eec8ba7e4b0> in getNearbyFoodVenues(df, radius)
#      22
#      23         # make the GET request
# ---> 24         results = requests.get(url).json()["response"]['groups'][0]['items']
#      25
#      26         # return only relevant information for each nearby venue
#
# C:\ProgramData\Anaconda3\lib\site-packages\requests\models.py in json(self, **kwargs)
#     895                     # used.
#     896                     pass
# --> 897         return complexjson.loads(self.text, **kwargs)
#     898
#     899     @property
#
# C:\ProgramData\Anaconda3\lib\json\__init__.py in loads(s, encoding, cls, object_hook, parse_float, parse_int, parse_constant, object_pairs_hook, **kw)
#     346             parse_int is None and parse_float is None and
#     347             parse_constant is None and object_pairs_hook is None and not kw):
# --> 348         return _default_decoder.decode(s)
#     349     if cls is None:
#     350         cls = JSONDecoder
#
# C:\ProgramData\Anaconda3\lib\json\decoder.py in decode(self, s, _w)
#     335
#     336         """
# --> 337         obj, end = self.raw_decode(s, idx=_w(s, 0).end())
#     338         end = _w(s, end).end()
#     339         if end != len(s):
#
# C:\ProgramData\Anaconda3\lib\json\decoder.py in raw_decode(self, s, idx)
#     353             obj, end = self.scan_once(s, idx)
#     354         except StopIteration as err:
# --> 355             raise JSONDecodeError("Expecting value", s, err.value) from None
#     356         return obj, end
#
# JSONDecodeError: Expecting value: line 1 column 1 (char 0)

# %%
# Save results to .csv so we don't have to keep hitting Foursquare
food_and_coords.shape
#venues.to_csv('los_angeles_venues.csv',sep='|')
# Out:
# (999, 9)

# %% [markdown]
# ## Create a map visualization

# %% [markdown]
# Define a function to plot markers for each venue

# %%
def mapVenues(df,map):
    # set color scheme for the clusters
    x = np.arange(df['Venue Category'].nunique())
    ys = [i + x + (i*x)**2 for i in range(df['Venue Category'].nunique())]
    colors_array = cm.rainbow(np.linspace(0, 1, len(ys)))
    rainbow = [colors.rgb2hex(i) for i in colors_array]

    # add markers to the map
    markers_colors = []
    for lat, lon, poi, cluster, cluster_desc in zip(
        df['Venue Latitude'], 
        df['Venue Longitude'], 
        df['Neighborhood'], 
        df['Category Number'], 
        df['Venue Category']):
    
        label = folium.Popup(str(poi) + '\n' + str(cluster_desc), parse_html=True)
        folium.CircleMarker(
            [lat, lon],
            radius=5,
            popup=label,
            color=rainbow[cluster-1],
            fill=True,
            fill_color=rainbow[cluster-1],
            fill_opacity=0.7).add_to(map)
    map

# %%
# create map
map_la = folium.Map(location=[34.24,-118.28], zoom_start=12)
mapVenues(venues,map_la)
map_la
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><iframe src="data:text/html;charset=utf-8;base64,..." style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %%
df.sort_values('lapophalfshare',ascending=0,inplace=True)

# %%
westwood_venues
# Out:
#                        Neighborhood                                   Venue  \
# 229  Westwood - Census Tract 265520                    Sunnin Lebanese Cafe
# 172  Westwood - Census Tract 265510                               Starbucks
# 118  Westwood - Census Tract 265305                             Diddy Riese
# 126  Westwood - Census Tract 265305               Lamonica's New York Pizza
# 290  Westwood - Census Tract 265700                              Clementine
# 242       34.047575      -118.443689                    Pizza Place
# 16        34.060794      -118.444562             Seafood Restaurant
# 21        34.063381      -118.441256                     Steakhouse
# 238       34.053836      -118.440475                     Restaurant
# 125       34.060733      -118.446843             Italian Restaurant
# 202       34.059532      -118.445625                         Bakery
# 173       34.055504      -118.441429             Persian Restaurant
# 160       34.057926      -118.443217                     Poke Place
# 49        34.060198      -118.445034                         Bakery
# 138       34.061136      -118.446240       Mediterranean Restaurant
# 124       34.060957      -118.446872             Chinese Restaurant
# 58        34.058980      -118.441370        New American Restaurant
# 134       34.059927      -118.446159               Sushi Restaurant
# 95        34.066824      -118.445696                 Sandwich Place
# 19        34.060568      -118.444347                    Salad Place
# 78        34.069349      -118.445377            American Restaurant
# 33        34.059800      -118.444741                     Poke Place
# 166       34.056502      -118.442646              Indian Restaurant
# 68        34.060044      -118.437401                     Restaurant
# 300       34.059070      -118.420017                    Pizza Place
# 293       34.059193      -118.420307                 Ice Cream Shop
# 291       34.059130      -118.420783             Mexican Restaurant
# 299       34.060702      -118.418746                    Pizza Place
# 30        34.061910      -118.444185                    Coffee Shop
# 303       34.059103      -118.420106                 Ice Cream Shop
# 297       34.060426      -118.418607             Italian Restaurant
# 85        34.068379      -118.442360                    Pizza Place
# 294       34.059310      -118.419797                    Coffee Shop
# 230       34.048136      -118.443169            Szechuan Restaurant
# 28        34.059567      -118.443697                     Restaurant
#
#      Category Number
# 229               14
# 172                1
# 118                5
# 126                2
# 290               18
# 234                7
# 117               24
# 139               20
# 253               35
# 39                 4
# 56                 1
# 280                1
# 121               28
# 259                9
# 228               15
# 15                 1
# 272                8
# 240                1
# 123                6
# 223               11
# 209               37
# 159                5
# 91                 8
# 129                2
# 161                3
# 304                3
# 194               42
# 153                1
# 97                17
# 246                1
# 130                2
# 34                38
# 217               27
# 190                7
# 215               25
# 292               23
# 169               11
# 137               36
# 252                3
# 216               11
# 255                2
# 237               34
# 79                 1
# 271               40
# 86                 9
# 100                1
# 218                2
# 269                5
# 257               16
# 101               12
# 102               18
# 268               15
# 93                 2
# 99                29
# 84                22
# 175               16
# 105                3
# 143                1
# 98                 1
# 205               16
# 96                 8
# 156                1
# 94                18
# 141                7
# 277                3
# 273                4
# 119                4
# 211               14
# 11                 1
# 198               14
# 90                 3
# 162               13
# 6                 33
# 32                26
# 92                23
# 279               17
# 157               10
# 158               30
# 203                3
# 224               19
# 302               31
# 104               43
# 103                4
# 275                8
# 42                13
# 35                 9
# 248               24
# 178               20
# 256               27
# 133                8
# 167                6
# 186                9
# 243               12
# 88                 7
# 29                 1
# 281               13
# 249                6
# 43                 4
# 258                1
# 204               32
# 278                6
# 200                4
# 227               12
# 242                2
# 16                17
# 21                41
# 238               10
# 125                3
# 202               19
# 173               11
# 160               21
# 49                19
# 138                6
# 124               12
# 58                13
# 134               15
# 95                 4
# 19                22
# 78                 7
# 33                21
# 166               25
# 68                10
# 300                2
# 293                5
# 291               26
# 299                2
# 30                 1
# 303                5
# 297                3
# 85                 2
# 294                1
# 230               39
# 28                10
